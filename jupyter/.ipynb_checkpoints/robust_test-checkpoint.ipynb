# %%
import sys
sys.path.append("../src/")
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
table_path='../final_data/for_robust/final_robust_test.csv'
final_data_df=pd.read_csv(table_path,sep=',')

# %%
final_data_df
# Out:
#        delta  classifier      loss   val_acc
# 0     1000.0         1.0  1.983447  0.571984
# 1     1000.0        10.0  3.279640  0.354086
# 2     1000.0        11.0  3.679912  0.307393
# 3     1000.0        12.0  3.598913  0.319066
# 4     1000.0        13.0  3.813710  0.361868
# ...      ...         ...       ...       ...
# 3025    90.0         5.0  0.603052  0.902724
# 3026    90.0         6.0  0.497329  0.918288
# 3027    90.0         7.0  0.566832  0.914397
# 3028    90.0         8.0  0.545364  0.918288
# 3029    90.0         9.0  0.522453  0.933852
#
# [3030 rows x 4 columns]

# %%
final_data_df=final_data_df.astype('float')

# %%
sns.set(font_scale=2)
plt.figure(figsize=(10,10))
sns.lineplot(data=final_data_df,x='delta',y='val_acc')
# plt.title('location interferce test')
# plt.savefig(r'location interferce test.png',dpi=200)
